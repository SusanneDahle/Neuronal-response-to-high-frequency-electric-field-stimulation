# %% [markdown]
# # Hay cell

# %%
# %matplotlib inline
import sys
import os
from os.path import join, expanduser

#from glob import glob
import numpy as np
import LFPy
import neuron

import matplotlib.pyplot as plt

# Add the parent directory of brainsignals to sys.path
parent_path = expanduser('~/Documents/Master/ElectricBrainSignals-main')
sys.path.append(parent_path)

import brainsignals.neural_simulations as ns
hay_folder = expanduser('~/Documents/Master/ElectricBrainSignals-main/brainsignals/cell_models/L5bPCmodelsEH')

from scipy.stats import mannwhitneyu
# Out:
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.

# %% [markdown]
# # Cell function

# %%
def return_hay_cell(tstop, dt):
    if not os.path.isfile(join(hay_folder, 'morphologies', 'cell1.asc')):
        ns.download_hay_model()

    if not hasattr(neuron.h, "CaDynamics_E2"):
        ns.neuron.load_mechanisms(join(hay_folder, 'mod'))
    cell_params = {
        'morphology': join(hay_folder, "morphologies", "cell1.asc"),
        'templatefile': [join(hay_folder, 'models', 'L5PCbiophys3.hoc'),
                            join(hay_folder, 'models', 'L5PCtemplate.hoc')],
        'templatename': 'L5PCtemplate',
        'templateargs': join(hay_folder, 'morphologies', 'cell1.asc'),
        'passive': False,
        'nsegs_method': None,
        'dt': dt,
        'tstart': -200,
        'tstop': tstop,
        'v_init': -75,
        'celsius': 34,
        'pt3d': True,
        'lambda_f': 500,
        'nsegs_method': 'lambda_f'
    }

    cell = LFPy.TemplateCell(**cell_params)

    cell.set_rotation(x=4.729, y=-3.166)
    return cell

# %% [markdown]
# # Simulation properties

# %%
tstop_active = 500
tstop_active_and_passive = 5000
dt = 2**-4
cutoff = 20

freq1 = np.arange(1, 10, 2)
freq2 = np.arange(10, 200, 20)
freq3 = np.arange(200, 300, 5)
freq4 = np.arange(300, 2001, 50)

freq = np.concatenate((freq1, freq2, freq3, freq4))

selected_freq = [10, 50, 110, 250, 300, 500, 1500, 2000]

# %%
print(freq)
# Out:
# [   1    3    5    7    9   10   30   50   70   90  110  130  150  170
#   190  200  205  210  215  220  225  230  235  240  245  250  255  260
#   265  270  275  280  285  290  295  300  350  400  450  500  550  600
#   650  700  750  800  850  900  950 1000 1050 1100 1150 1200 1250 1300
#  1350 1400 1450 1500 1550 1600 1650 1700 1750 1800 1850 1900 1950 2000]

# %% [markdown]
# # Simulation function, Active hay cell, strong E-field

# %%
soma_amplitudes = []
plot_data = {}

def sim_active_hay_neuron(freq, tstop, dt, cutoff, local_E_field=500):

    global soma_amplitudes, plot_data
    soma_amplitudes = []
    plot_data = {}

    local_ext_pot = np.vectorize(lambda x, y, z: local_E_field * z / 1000)
    n_tsteps_ = int((tstop + cutoff) / dt + 1)
    t_ = np.arange(n_tsteps_) * dt

    # Loop over each frequency
    for f in freq:
        # Re-import the cell model
        cell = return_hay_cell(tstop, dt)
        cell.extracellular = True
    
        for sec in cell.allseclist:
            sec.insert("extracellular")
    
        # Compute base potential
        base_pot = local_ext_pot(
            cell.x.mean(axis=-1),
            cell.y.mean(axis=-1),
            cell.z.mean(axis=-1)
        ).reshape(cell.totnsegs, 1)
    
        # Generate the pulse for the current frequency
        pulse = np.sin(2 * np.pi * f * t_ / 1000)
        
        # Prepare the external potential array
        v_cell_ext = np.zeros((cell.totnsegs, n_tsteps_))
        v_cell_ext = base_pot * pulse.reshape(1, n_tsteps_)
    
        # Apply the external potential and simulate the cell
        cell.insert_v_ext(v_cell_ext, t_)
        cell.simulate(rec_vmem=True)
    
        # Calculate the amplitude of the soma potential
        # Max and min / 2 to show spiking or not spiking
        stable_time = cell.tvec[cell.tvec > 150]
        stable_vmem = cell.vmem[0, cell.tvec > 150]
        amplitude = (np.max(stable_vmem) - np.min(stable_vmem)) / 2
    
        soma_amplitudes.append(amplitude)

        # Store plot data ----
        apic_idx1 = cell.get_closest_idx(z=1000)
        apic_idx2 = cell.get_closest_idx(z=-100)
        selected_segments = [0, apic_idx1, apic_idx2]

        # Initialize dictionary for plot data
        if f == selected_freq[0]:
            plot_data = {
                "freq": [],
                "x": cell.x.tolist(),
                "z": cell.z.tolist(),
                "totnsegs": cell.totnsegs,
                "tvec": cell.tvec.tolist(),
                "selected_segments": selected_segments,
                "colors": ['tab:blue', 'tab:orange', 'tab:olive'],
                "soma_vmem": [],
                "idx1_vmem": [],
                "idx2_vmem": []
            }            

        # Store plot-data for some of the frequencies
        if f in selected_freq:
            plot_data['freq'].append(f)
            plot_data['soma_vmem'].append(cell.vmem[0].tolist())
            plot_data['idx1_vmem'].append(cell.vmem[selected_segments[1]].tolist())
            plot_data['idx2_vmem'].append(cell.vmem[selected_segments[2]].tolist())

        print(f'{f}Hz complete')
        # Delete the cell before next frequency
        del cell

# %%
sim_active_hay_neuron(freq=freq, tstop=tstop_active, dt=dt, cutoff=cutoff)
# Out:
# 1Hz complete
# 3Hz complete
# 5Hz complete
# 7Hz complete
# 9Hz complete
# 10Hz complete
# 30Hz complete
# 50Hz complete
# 70Hz complete
# 90Hz complete
# 110Hz complete
# 130Hz complete
# 150Hz complete
# 170Hz complete
# 190Hz complete
# 200Hz complete
# 205Hz complete
# 210Hz complete
# 215Hz complete
# 220Hz complete
# 225Hz complete
# 230Hz complete
# 235Hz complete
# 240Hz complete
# 245Hz complete
# 250Hz complete
# 255Hz complete
# 260Hz complete
# 265Hz complete
# 270Hz complete
# 275Hz complete
# 280Hz complete
# 285Hz complete
# 290Hz complete
# 295Hz complete
# 300Hz complete
# 350Hz complete
# 400Hz complete
# 450Hz complete
# 500Hz complete
# 550Hz complete
# 600Hz complete
# 650Hz complete
# 700Hz complete
# 750Hz complete
# 800Hz complete
# 850Hz complete
# 900Hz complete
# 950Hz complete
# 1000Hz complete
# 1050Hz complete
# 1100Hz complete
# 1150Hz complete
# 1200Hz complete
# 1250Hz complete
# 1300Hz complete
# 1350Hz complete
# 1400Hz complete
# 1450Hz complete
# 1500Hz complete
# 1550Hz complete
# 1600Hz complete
# 1650Hz complete
# 1700Hz complete
# 1750Hz complete
# 1800Hz complete
# 1850Hz complete
# 1900Hz complete
# 1950Hz complete
# 2000Hz complete

# %%
def plot_vmem(plot_data):
    numrows = 2
    numcols = len(plot_data['freq'])//2 + 1
    fig, axes = plt.subplots(numrows, numcols, figsize=(12, 4), gridspec_kw={'height_ratios': [1, 1], 'width_ratios': [1] * numcols})

    for row in range(numrows):
        axes[row,0].set_xticks([])
        axes[row,0].set_yticks([])
        axes[row,0].set_frame_on(False)
    
    selected_segments = plot_data['selected_segments']
    #colors = plot_data['colors']
    colors = ['tab:blue', 'tab:orange', 'tab:olive']

    totnsegs = int(plot_data['totnsegs'])
    x = np.array(plot_data['x'])
    z = np.array(plot_data['z'])
    tvec = np.array(plot_data['tvec'])
    selected_segments = plot_data['selected_segments']
    soma_vmem = np.array(plot_data['soma_vmem'])
    idx1_vmem = np.array(plot_data['idx1_vmem'])
    idx2_vmem = np.array(plot_data['idx2_vmem'])

    # Add label A above morphology plots
    fig.text(0.01, 0.98, 'A', fontsize=16, fontweight='bold', va='top', ha='center')
    
    # First column: Cell shape
    ax1 = plt.subplot2grid((numrows, numcols), (0, 0), rowspan=2)
    ax1.set_aspect(1)
    ax1.set_xticks([])
    ax1.set_xlabel('x [µm]')
    ax1.set_ylabel('z [µm]')
    #ax1.set_title("Active hay neuron", fontsize=14)

    for idx_seg in range(totnsegs):
        ax1.plot(x[idx_seg], z[idx_seg], c='k')

    for idx, color in zip(selected_segments, colors):
        ax1.plot(x.mean(axis=-1)[idx], z.mean(axis=-1)[idx], 'o', color=color, label=f"Segment {idx}")
    
    #ax1.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=3, frameon=False)

    # Add label B above the membrane potential plots
    fig.text(0.15, 0.98, 'B', fontsize=16, fontweight='bold', va='top', ha='center')

    for i, f in enumerate(plot_data['freq']):
        row = i//4 #Gives 0 for the first 4
        col = (i % 4) + 1 #What remains after i is devided by 4 
        ax = axes[row,col]
        ax.set_xlabel('Time [ms]')
        ax.set_ylabel('Membrane Potential [mV]')
        ax.set_title(f"{f} Hz", fontsize=12)
        ax.plot(tvec, idx1_vmem[i], color=colors[1], label=f'Segment {selected_segments[1]}', linewidth = 1, alpha = 0.7)
        ax.plot(tvec, idx2_vmem[i], color=colors[2], label=f'Segment {selected_segments[2]}', linewidth = 1, alpha = 0.7)
        ax.plot(tvec, soma_vmem[i], color=colors[0], label='Soma', linewidth = 1, alpha = 0.9)

        #ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=3, frameon=False)

    # Create a common legend underneath all plots
    handles = [
        plt.Line2D([0], [0], color=colors[0], label='Soma', linewidth=1, alpha=0.9),
        plt.Line2D([0], [0], color=colors[1], label=f'Segment {selected_segments[1]}', linewidth=1, alpha=0.7),
        plt.Line2D([0], [0], color=colors[2], label=f'Segment {selected_segments[2]}', linewidth=1, alpha=0.7)
    ]

    fig.legend(handles=handles, loc='lower center', bbox_to_anchor=(0.5, -0.1), ncol=3, frameon=False)

    fig.set_constrained_layout(True)
    plt.savefig('Hay_cell_active_cell_shape_and_vmem_plots')
    plt.show()

plot_vmem(plot_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.gridspec import GridSpec

def plot_vmem(plot_data):
    numrows = 2
    numcols = len(plot_data['freq']) // 2 + 1  # +1 for morphology column

    # Use constrained_layout and GridSpec for control
    fig = plt.figure(figsize=(12, 5), constrained_layout=True)
    gs = GridSpec(3, numcols, figure=fig, height_ratios=[10, 10, 1])  # 2 rows of plots + 1 row for legend

    axes = np.empty((2, numcols), dtype=object)  # Placeholder for axes refs

    # Plot A: Morphology (rowspan 2, col 0)
    ax1 = fig.add_subplot(gs[0:2, 0])
    ax1.set_aspect(1)
    ax1.set_xticks([])
    ax1.set_yticks([])
    ax1.set_xlabel('x [µm]')
    ax1.set_ylabel('z [µm]')

    totnsegs = int(plot_data['totnsegs'])
    x = np.array(plot_data['x'])
    z = np.array(plot_data['z'])
    selected_segments = plot_data['selected_segments']
    colors = ['tab:blue', 'tab:orange', 'tab:olive']

    for idx_seg in range(totnsegs):
        ax1.plot(x[idx_seg], z[idx_seg], c='k')

    for idx, color in zip(selected_segments, colors):
        ax1.plot(x.mean(axis=-1)[idx], z.mean(axis=-1)[idx], 'o', color=color, label=f"Segment {idx}", markersize = 8)

    ax1.text(-0.15, 1.05, 'A', transform=ax1.transAxes, fontsize=16, fontweight='bold')

    # Plot B: Membrane potentials
    tvec = np.array(plot_data['tvec'])
    soma_vmem = np.array(plot_data['soma_vmem'])
    idx1_vmem = np.array(plot_data['idx1_vmem'])
    idx2_vmem = np.array(plot_data['idx2_vmem'])

    for i, f in enumerate(plot_data['freq']):
        row = i // (numcols - 1)
        col = (i % (numcols - 1)) + 1  # +1 because col 0 is morphology

        ax = fig.add_subplot(gs[row, col])
        axes[row, col] = ax

        ax.set_xlabel('Time [ms]')
        ax.set_ylabel('Membrane Potential [mV]')
        ax.set_title(f"{f} Hz", fontsize=12)

        ax.plot(tvec, idx1_vmem[i], color=colors[1], label=f'Segment {selected_segments[1]}', linewidth=1, alpha=0.7)
        ax.plot(tvec, idx2_vmem[i], color=colors[2], label=f'Segment {selected_segments[2]}', linewidth=1, alpha=0.7)
        ax.plot(tvec, soma_vmem[i], color=colors[0], label='Soma', linewidth=1, alpha=0.9)

        if row == 0 and col == 1:
            ax.text(-0.15, 1.12, 'B', transform=ax.transAxes, fontsize=16, fontweight='bold')

    # Legend (bottom row, spanning all columns)
    legend_ax = fig.add_subplot(gs[2, :])
    legend_ax.axis('off')

    handles = [
        plt.Line2D([0], [0], color=colors[0], label='Soma', linewidth=2, alpha=0.9),
        plt.Line2D([0], [0], color=colors[1], label=f'Segment {selected_segments[1]}', linewidth=2, alpha=0.7),
        plt.Line2D([0], [0], color=colors[2], label=f'Segment {selected_segments[2]}', linewidth=2, alpha=0.7)
    ]
    legend_ax.legend(handles=handles, loc='center', ncol=3, frameon=False, fontsize = 14)

    plt.savefig('Hay_cell_active_cell_shape_and_vmem_plots.png', dpi=300)
    plt.show()
plot_vmem(plot_data)

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
plt.loglog(freq, soma_amplitudes, linestyle='-', color='tab:blue', markersize=5, linewidth=2, label = 'Active hay neuron')
plt.xlabel('Frequency [Hz]', fontsize=14)
plt.ylabel('Soma Vmem Amplitude [mV]', fontsize=14)
plt.legend()
plt.title('Soma Vmem Amplitude vs Frequency', fontsize=16)
plt.xlim(left=1)  # Start the x-axis from 2
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout() 
plt.savefig('Hay_cell_active_soma_amp_vs_freq')
plt.show()

# %% [markdown]
# # Simulation function, Active and Passive hay cell, weaker E-field

# %%
soma_amplitudes_active_old = []
soma_amplitudes_passive_old = []
plot_data_both_old = {}

def sim_a_and_p_hay_neuron_old(freq, tstop, dt, cutoff, local_E_field=1):

    global soma_amplitudes_active_old, soma_amplitudes_passive_old, plot_data_both_old
    soma_amplitudes_active_old = []
    soma_amplitudes_passive_old = []
    plot_data_both_old = {}

    local_ext_pot = np.vectorize(lambda x, y, z: local_E_field * z / 1000)
    n_tsteps_ = int((tstop + cutoff) / dt + 1)
    t_ = np.arange(n_tsteps_) * dt

    hay_cells = ['Active', 'Passive']


    for cell_idx in range(len(hay_cells)):
        cell_type = hay_cells[cell_idx]

        if cell_type == 'Active':
            make_passive = False
        if cell_type == 'Passive':
            make_passive = True 
                 
        # Loop over each frequency
        for f in freq:
            # Re-import the cell model
            cell = return_hay_cell(tstop, dt)
            cell.extracellular = True
        
            for sec in cell.allseclist:
                sec.insert("extracellular")
        
            # Compute base potential
            base_pot = local_ext_pot(
                cell.x.mean(axis=-1),
                cell.y.mean(axis=-1),
                cell.z.mean(axis=-1)
            ).reshape(cell.totnsegs, 1)
        
            # Generate the pulse for the current frequency
            pulse = np.sin(2 * np.pi * f * t_ / 1000)
            
            # Prepare the external potential array
            v_cell_ext = np.zeros((cell.totnsegs, n_tsteps_))
            v_cell_ext = base_pot * pulse.reshape(1, n_tsteps_)
        
            # Apply the external potential and simulate the cell
            cell.insert_v_ext(v_cell_ext, t_)
            cell.simulate(rec_vmem=True)
        
            # Calculate the amplitude of the soma potential
            cut_tvec = cell.tvec[cell.tvec > 2000]
            cut_soma_vmem = cell.vmem[0, cell.tvec > 2000]
            soma_amp = (np.max(cut_soma_vmem) - np.min(cut_soma_vmem)) / 2

            if cell_type == 'Active':
                soma_amplitudes_active_old.append(soma_amp)
            if cell_type == 'Passive':
                soma_amplitudes_passive_old.append(soma_amp)
                
    
            # Initialize dictionary for plot data 
            if f == selected_freq[0]:
                plot_data_both_old[cell_type] = {
                    "freq": [],
                    "x": cell.x.tolist(),
                    "z": cell.z.tolist(),
                    "totnsegs": cell.totnsegs,
                    "tvec": cell.tvec.tolist(),
                    "selected_segments": [0, cell.get_closest_idx(z=1000), cell.get_closest_idx(z=-100)],
                    "colors": ['tab:blue', 'tab:orange', 'tab:green'],
                    "soma_vmem": [],
                    "idx1_vmem": [],
                    "idx2_vmem": []
                }            
    
            # Store plot-data for some of the frequencies
            if f in selected_freq:
                plot_data_both_old[cell_type]['freq'].append(f)
                plot_data_both_old[cell_type]['soma_vmem'].append(cell.vmem[0].tolist())
                plot_data_both_old[cell_type]['idx1_vmem'].append(cell.vmem[cell.get_closest_idx(z=1000)].tolist())
                plot_data_both_old[cell_type]['idx2_vmem'].append(cell.vmem[cell.get_closest_idx(z=-100)].tolist())

            print(f'{f}Hz complete for {cell_type}')
            # Delete the cell before next frequency
            del cell
        print(f'Simulation for {cell_type} hay cell complete')

# %%
sim_a_and_p_hay_neuron_old(freq=freq, tstop=tstop_active_and_passive, dt=dt, cutoff=cutoff)
# Out:
# 1Hz complete for Active
# 3Hz complete for Active
# 5Hz complete for Active
# 7Hz complete for Active
# 9Hz complete for Active
# 10Hz complete for Active
# 30Hz complete for Active
# 50Hz complete for Active
# 70Hz complete for Active
# 90Hz complete for Active
# 110Hz complete for Active
# 130Hz complete for Active
# 150Hz complete for Active
# 170Hz complete for Active
# 190Hz complete for Active
# 200Hz complete for Active
# 205Hz complete for Active
# 210Hz complete for Active
# 215Hz complete for Active
# 220Hz complete for Active
# 225Hz complete for Active
# 230Hz complete for Active
# 235Hz complete for Active
# 240Hz complete for Active
# 245Hz complete for Active
# 250Hz complete for Active
# 255Hz complete for Active
# 260Hz complete for Active
# 265Hz complete for Active
#
# parse error
# itok=1 on line 0 token=eof x=0 s=
# line 0:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sim_a_and_p_hay_neuron_old(freq=freq, tstop=tstop_active_and_passive, dt=dt, cutoff=cutoff)
#
# Cell In[10], line 30, in sim_a_and_p_hay_neuron_old(freq, tstop, dt, cutoff, local_E_field)
#      27 # Loop over each frequency
#      28 for f in freq:
#      29     # Re-import the cell model
# ---> 30     cell = return_hay_cell(tstop, dt)
#      31     cell.extracellular = True
#      33     for sec in cell.allseclist:
#
# Cell In[3], line 25, in return_hay_cell(tstop, dt)
#       6     ns.neuron.load_mechanisms(join(hay_folder, 'mod'))
#       7 cell_params = {
#       8     'morphology': join(hay_folder, "morphologies", "cell1.asc"),
#       9     'templatefile': [join(hay_folder, 'models', 'L5PCbiophys3.hoc'),
#    (...)
#      22     'nsegs_method': 'lambda_f'
#      23 }
# ---> 25 cell = LFPy.TemplateCell(**cell_params)
#      27 cell.set_rotation(x=4.729, y=-3.166)
#      28 return cell
#
# File /opt/anaconda3/lib/python3.12/site-packages/LFPy/templatecell.py:148, in TemplateCell.__init__(self, templatefile, templatename, templateargs, verbose, **kwargs)
#     145             neuron.h.load_file(template)
#     147 # initialize the parent Cell object
# --> 148 super().__init__(**kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/LFPy/cell.py:275, in Cell.__init__(self, morphology, v_init, Ra, cm, passive, passive_parameters, extracellular, tstart, tstop, dt, nsegs_method, lambda_f, d_lambda, max_nsegs_length, delete_sections, custom_code, custom_fun, custom_fun_args, pt3d, celsius, verbose, **kwargs)
#     273 # Gather geometry, set position morphology
#     274 if self.pt3d:
# --> 275     self._update_pt3d()
#     276 else:  # self._update_pt3d makes a call to self._collect_geometry()
#     277     self._collect_geometry()
#
# File /opt/anaconda3/lib/python3.12/site-packages/LFPy/cell.py:2028, in Cell._update_pt3d(self)
#    2026     neuron.h.define_shape()
#    2027 # must recollect the geometry, otherwise we get roundoff errors!
# -> 2028 self._collect_geometry()
#
# File /opt/anaconda3/lib/python3.12/site-packages/LFPy/cell.py:703, in Cell._collect_geometry(self)
#     701 self.somaidx = np.array([0])
#     702 self.somapos = np.zeros(3)
# --> 703 self.somapos[0] = self.x[self.somaidx].mean()
#     704 self.somapos[1] = self.y[self.somaidx].mean()
#     705 self.somapos[2] = self.z[self.somaidx].mean()
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
max_dif = 0.00001

for i in range(len(freq)):
    dif = abs(soma_amplitudes_active_old[i] - soma_amplitudes_passive_old[i])
    if dif >= max_dif:
        max_dif = dif
        print(f'Max difference is {max_dif} mV at {freq[i]}Hz')
# Out:
# Max difference is 0.006231028612120326 mV at 1Hz
# Max difference is 0.009618918063317494 mV at 3Hz
# Max difference is 0.010248156379788043 mV at 5Hz
# Max difference is 0.014105794236172642 mV at 9Hz
# Max difference is 0.017938651016514484 mV at 10Hz

# %% [markdown]
# ### With remove list and Fourier

# %%
soma_amplitudes_active = []
soma_amplitudes_passive = []
plot_data_both = {}

remove_list = ["Ca_HVA", "Ca_LVAst", "CaDynamics_E2", "epsp2", "Ih", "Im", "K_Pst", "K_Tst", "Nap_Et2", "NaTa_t", "NaTs2_t", "SK_E2", "SKv3_1"]


def sim_a_and_p_hay_neuron(freq, tstop, dt, cutoff, local_E_field=1):

    global soma_amplitudes_active, soma_amplitudes_passive, plot_data_both
    soma_amplitudes_active = []
    soma_amplitudes_passive = []
    plot_data_both = {}

    local_ext_pot = np.vectorize(lambda x, y, z: local_E_field * z / 1000)
    n_tsteps_ = int((tstop + cutoff) / dt + 1)
    t_ = np.arange(n_tsteps_) * dt

    hay_cells = ['Active', 'Passive']

    for cell_idx in range(len(hay_cells)):
        cell_type = hay_cells[cell_idx]
                 
        # Loop over each frequency
        for f in freq:
            # Re-import the cell model for each frequency
            
            if cell_type == 'Active':
                cell = return_hay_cell(tstop, dt)
            if cell_type == 'Passive':
                cell = return_hay_cell(tstop, dt)
                ns.remove_active_mechanisms(remove_list, cell)
                
            cell.extracellular = True
        
            for sec in cell.allseclist:
                sec.insert("extracellular")
        
            # Compute base potential
            base_pot = local_ext_pot(
                cell.x.mean(axis=-1),
                cell.y.mean(axis=-1),
                cell.z.mean(axis=-1)
            ).reshape(cell.totnsegs, 1)
        
            # Generate the pulse for the current frequency
            pulse = np.sin(2 * np.pi * f * t_ / 1000)
            
            # Prepare the external potential array
            v_cell_ext = np.zeros((cell.totnsegs, n_tsteps_))
            v_cell_ext = base_pot * pulse.reshape(1, n_tsteps_)
        
            # Apply the external potential and simulate the cell
            cell.insert_v_ext(v_cell_ext, t_)
            cell.simulate(rec_vmem=True)
        
            # Calculate the amplitude of the soma potential
            cut_tvec = cell.tvec[cell.tvec > 2000]
            cut_soma_vmem = cell.vmem[0, cell.tvec > 2000]
            freqs, vmem_amps = ns.return_freq_and_amplitude(cut_tvec, cut_soma_vmem)
            freq_idx = np.argmin(np.abs(freqs - f))
            soma_amp = vmem_amps[0, freq_idx]
            print(f'freq from ff: {freqs[freq_idx]}, actual freq: {f}')
            print(f'amp from ff: {soma_amp}, fom max-min/2 {(np.max(cut_soma_vmem) - np.min(cut_soma_vmem)) / 2}')

            if cell_type == 'Active':
                soma_amplitudes_active.append(soma_amp)
            if cell_type == 'Passive':
                soma_amplitudes_passive.append(soma_amp)
                
    
            # Initialize dictionary for plot data 
            if f == selected_freq[0]:
                plot_data_both[cell_type] = {
                    "freq": [],
                    "x": cell.x.tolist(),
                    "z": cell.z.tolist(),
                    "totnsegs": cell.totnsegs,
                    "tvec": cell.tvec.tolist(),
                    "selected_segments": [0, cell.get_closest_idx(z=1000), cell.get_closest_idx(z=-100)],
                    "colors": ['tab:blue', 'tab:orange', 'tab:green'],
                    "soma_vmem": [],
                    "idx1_vmem": [],
                    "idx2_vmem": []
                }            
    
            # Store plot-data for some of the frequencies
            if f in selected_freq:
                plot_data_both[cell_type]['freq'].append(f)
                plot_data_both[cell_type]['soma_vmem'].append(cell.vmem[0].tolist())
                plot_data_both[cell_type]['idx1_vmem'].append(cell.vmem[cell.get_closest_idx(z=1000)].tolist())
                plot_data_both[cell_type]['idx2_vmem'].append(cell.vmem[cell.get_closest_idx(z=-100)].tolist())

            print(f'{f}Hz complete for {cell_type}')
            # Delete the cell before next frequency
            del cell
        print(f'Simulation for {cell_type} hay cell complete')

# %%
sim_a_and_p_hay_neuron(freq=freq, tstop=tstop_active_and_passive, dt=dt, cutoff=cutoff)
# Out:
# freq from ff: 1.0, actual freq: 1
# amp from ff: 0.2092056600062792, fom max-min/2 0.20977776670090265
# 1Hz complete for Active
# freq from ff: 3.0, actual freq: 3
# amp from ff: 0.22118488694408117, fom max-min/2 0.22229732312722916
# 3Hz complete for Active
# freq from ff: 5.0, actual freq: 5
# amp from ff: 0.2156045282868317, fom max-min/2 0.21684016167723286
# 5Hz complete for Active
# freq from ff: 7.0, actual freq: 7
# amp from ff: 0.19501705887844398, fom max-min/2 0.19630397218201523
# 7Hz complete for Active
# freq from ff: 9.0, actual freq: 9
# amp from ff: 0.174252192479984, fom max-min/2 0.17556813760367618
# 9Hz complete for Active
# freq from ff: 10.0, actual freq: 10
# amp from ff: 0.1657801422018538, fom max-min/2 0.16710690503336423
# 10Hz complete for Active
# freq from ff: 30.0, actual freq: 30
# amp from ff: 0.09532185248497264, fom max-min/2 0.09672062251098623
# 30Hz complete for Active
# freq from ff: 50.0, actual freq: 50
# amp from ff: 0.0671143877150779, fom max-min/2 0.06853057771451887
# 50Hz complete for Active
# freq from ff: 70.0, actual freq: 70
# amp from ff: 0.05232661859845864, fom max-min/2 0.05375024976925147
# 70Hz complete for Active
# freq from ff: 90.0, actual freq: 90
# amp from ff: 0.04347089881253615, fom max-min/2 0.044898237164275656
# 90Hz complete for Active
# freq from ff: 110.0, actual freq: 110
# amp from ff: 0.03769988581767501, fom max-min/2 0.0391293149779699
# 110Hz complete for Active
# freq from ff: 130.0, actual freq: 130
# amp from ff: 0.03372366885398725, fom max-min/2 0.035154670575579416
# 130Hz complete for Active
# freq from ff: 150.0, actual freq: 150
# amp from ff: 0.030871569264618984, fom max-min/2 0.03230310128726188
# 150Hz complete for Active
# freq from ff: 170.0, actual freq: 170
# amp from ff: 0.028759595746543135, fom max-min/2 0.03019495161338881
# 170Hz complete for Active
# freq from ff: 190.0, actual freq: 190
# amp from ff: 0.02715265157023672, fom max-min/2 0.028588335217023086
# 190Hz complete for Active
# freq from ff: 200.0, actual freq: 200
# amp from ff: 0.026489155242126187, fom max-min/2 0.02792390035899217
# 200Hz complete for Active
# freq from ff: 205.0, actual freq: 205
# amp from ff: 0.02618596480246442, fom max-min/2 0.027617514204756333
# 205Hz complete for Active
# freq from ff: 210.0, actual freq: 210
# amp from ff: 0.025899814390583108, fom max-min/2 0.02732884398052704
# 210Hz complete for Active
# freq from ff: 215.0, actual freq: 215
# amp from ff: 0.025629377059336926, fom max-min/2 0.02706542385826083
# 215Hz complete for Active
# freq from ff: 220.0, actual freq: 220
# amp from ff: 0.025373446123831505, fom max-min/2 0.02680926446859644
# 220Hz complete for Active
# freq from ff: 225.0, actual freq: 225
# amp from ff: 0.025130922791876207, fom max-min/2 0.026556209412362364
# 225Hz complete for Active
# freq from ff: 230.0, actual freq: 230
# amp from ff: 0.02490080524426325, fom max-min/2 0.026337489217006294
# 230Hz complete for Active
# freq from ff: 235.0, actual freq: 235
# amp from ff: 0.024682178969697398, fom max-min/2 0.02611571015362557
# 235Hz complete for Active
# freq from ff: 240.0, actual freq: 240
# amp from ff: 0.024474208189318964, fom max-min/2 0.025907181750014274
# 240Hz complete for Active
# freq from ff: 245.0, actual freq: 245
# amp from ff: 0.024276128230673374, fom max-min/2 0.025712494855625323
# 245Hz complete for Active
# freq from ff: 250.0, actual freq: 250
# amp from ff: 0.024087238731566277, fom max-min/2 0.025509932682794556
# 250Hz complete for Active
# freq from ff: 255.0, actual freq: 255
# amp from ff: 0.023906897571542133, fom max-min/2 0.025343906313509024
# 255Hz complete for Active
# freq from ff: 260.0, actual freq: 260
# amp from ff: 0.02373451544291405, fom max-min/2 0.025165108977695638
# 260Hz complete for Active
# freq from ff: 265.0, actual freq: 265
# amp from ff: 0.023569550985658428, fom max-min/2 0.025005480858609985
# 265Hz complete for Active
# freq from ff: 270.0, actual freq: 270
# amp from ff: 0.023411506420387255, fom max-min/2 0.024845675978447446
# 270Hz complete for Active
# freq from ff: 275.0, actual freq: 275
# amp from ff: 0.023259923622474313, fom max-min/2 0.02469095683597544
# 275Hz complete for Active
# freq from ff: 280.0, actual freq: 280
# amp from ff: 0.023114380587671752, fom max-min/2 0.024552228945424304
# 280Hz complete for Active
# freq from ff: 285.0, actual freq: 285
# amp from ff: 0.022974488245860927, fom max-min/2 0.024396996532246362
# 285Hz complete for Active
# freq from ff: 290.0, actual freq: 290
# amp from ff: 0.02283988758495422, fom max-min/2 0.024276835340039327
# 290Hz complete for Active
# freq from ff: 295.0, actual freq: 295
# amp from ff: 0.02271024705159481, fom max-min/2 0.024145525502547116
# 295Hz complete for Active
# freq from ff: 300.0, actual freq: 300
# amp from ff: 0.02258526019930945, fom max-min/2 0.024008829669192266
# 300Hz complete for Active
# freq from ff: 350.0, actual freq: 350
# amp from ff: 0.021538145671645925, fom max-min/2 0.02296257555874348
# 350Hz complete for Active
# freq from ff: 400.0, actual freq: 400
# amp from ff: 0.02074372828039371, fom max-min/2 0.022140751737623532
# 400Hz complete for Active
# freq from ff: 450.0, actual freq: 450
# amp from ff: 0.020102614240903687, fom max-min/2 0.02153647509911849
# 450Hz complete for Active
# freq from ff: 500.0, actual freq: 500
# amp from ff: 0.019562297021343156, fom max-min/2 0.020919467053573726
# 500Hz complete for Active
# freq from ff: 550.0, actual freq: 550
# amp from ff: 0.019093089107253224, fom max-min/2 0.020507472788345638
# 550Hz complete for Active
# freq from ff: 600.0, actual freq: 600
# amp from ff: 0.01867707990153593, fom max-min/2 0.020107840535501964
# 600Hz complete for Active
# freq from ff: 650.0, actual freq: 650
# amp from ff: 0.01830277913485814, fom max-min/2 0.019743168597216254
# 650Hz complete for Active
# freq from ff: 700.0, actual freq: 700
# amp from ff: 0.017962383828722922, fom max-min/2 0.019391480732281252
# 700Hz complete for Active
# freq from ff: 750.0, actual freq: 750
# amp from ff: 0.017650317636979117, fom max-min/2 0.019072703801512603
# 750Hz complete for Active
# freq from ff: 800.0, actual freq: 800
# amp from ff: 0.017362415581533522, fom max-min/2 0.01867264863005147
# 800Hz complete for Active
# freq from ff: 850.0, actual freq: 850
# amp from ff: 0.01709544978338567, fom max-min/2 0.01853713623077624
# 850Hz complete for Active
# freq from ff: 900.0, actual freq: 900
# amp from ff: 0.016846842264946253, fom max-min/2 0.0182778907042902
# 900Hz complete for Active
# freq from ff: 950.0, actual freq: 950
# amp from ff: 0.016614484072470355, fom max-min/2 0.018049383103615924
# 950Hz complete for Active
# freq from ff: 1000.0, actual freq: 1000
# amp from ff: 0.01639661690698691, fom max-min/2 0.017834794039877977
# 1000Hz complete for Active
# freq from ff: 1050.0, actual freq: 1050
# amp from ff: 0.01619175273960879, fom max-min/2 0.017629641504044002
# 1050Hz complete for Active
# freq from ff: 1100.0, actual freq: 1100
# amp from ff: 0.01599861727184572, fom max-min/2 0.01742684394033489
# 1100Hz complete for Active
# freq from ff: 1150.0, actual freq: 1150
# amp from ff: 0.015816108853465776, fom max-min/2 0.017246978059439755
# 1150Hz complete for Active
# freq from ff: 1200.0, actual freq: 1200
# amp from ff: 0.015643267741752166, fom max-min/2 0.017037159582152128
# 1200Hz complete for Active
# freq from ff: 1250.0, actual freq: 1250
# amp from ff: 0.015479252494433493, fom max-min/2 0.016921439307289177
# 1250Hz complete for Active
# freq from ff: 1300.0, actual freq: 1300
# amp from ff: 0.015323321429478728, fom max-min/2 0.0167514474600452
# 1300Hz complete for Active
# freq from ff: 1350.0, actual freq: 1350
# amp from ff: 0.015174817783432711, fom max-min/2 0.016602038734610858
# 1350Hz complete for Active
# freq from ff: 1400.0, actual freq: 1400
# amp from ff: 0.015033157638120544, fom max-min/2 0.01647193651276524
# 1400Hz complete for Active
# freq from ff: 1450.0, actual freq: 1450
# amp from ff: 0.014897819966720573, fom max-min/2 0.01630498307992667
# 1450Hz complete for Active
# freq from ff: 1500.0, actual freq: 1500
# amp from ff: 0.014768338335038421, fom max-min/2 0.016205492512632702
# 1500Hz complete for Active
# freq from ff: 1550.0, actual freq: 1550
# amp from ff: 0.0146442939181101, fom max-min/2 0.01605819499030048
# 1550Hz complete for Active
# freq from ff: 1600.0, actual freq: 1600
# amp from ff: 0.014525309577869317, fom max-min/2 0.015949030102973438
# 1600Hz complete for Active
# freq from ff: 1650.0, actual freq: 1650
# amp from ff: 0.014411044807682728, fom max-min/2 0.015852693936999174
# 1650Hz complete for Active
# freq from ff: 1700.0, actual freq: 1700
# amp from ff: 0.014301191393001327, fom max-min/2 0.015730086423367595
# 1700Hz complete for Active
# freq from ff: 1750.0, actual freq: 1750
# amp from ff: 0.01419546966886112, fom max-min/2 0.015625858986879848
# 1750Hz complete for Active
# freq from ff: 1800.0, actual freq: 1800
# amp from ff: 0.014093625278973385, fom max-min/2 0.015516074303903338
# 1800Hz complete for Active
# freq from ff: 1850.0, actual freq: 1850
# amp from ff: 0.013995426359029173, fom max-min/2 0.015427412275130337
# 1850Hz complete for Active
# freq from ff: 1900.0, actual freq: 1900
# amp from ff: 0.013900661080855286, fom max-min/2 0.01534100789800874
# 1900Hz complete for Active
# freq from ff: 1950.0, actual freq: 1950
# amp from ff: 0.01380913550508854, fom max-min/2 0.015231171994990689
# 1950Hz complete for Active
# freq from ff: 2000.0, actual freq: 2000
# amp from ff: 0.013720671698695872, fom max-min/2 0.014386018068712758
# 2000Hz complete for Active
# Simulation for Active hay cell complete
# freq from ff: 1.0, actual freq: 1
# amp from ff: 0.2299584290987912, fom max-min/2 0.22995842898180285
# 1Hz complete for Passive
# freq from ff: 3.0, actual freq: 3
# amp from ff: 0.22055245012551505, fom max-min/2 0.22055244992402834
# 3Hz complete for Passive
# freq from ff: 5.0, actual freq: 5
# amp from ff: 0.20764314274606363, fom max-min/2 0.20764314232353343
# 5Hz complete for Passive
# freq from ff: 7.0, actual freq: 7
# amp from ff: 0.194179553995847, fom max-min/2 0.19417955192656677
# 7Hz complete for Passive
# freq from ff: 9.0, actual freq: 9
# amp from ff: 0.18113017953084973, fom max-min/2 0.18113017936077824
# 9Hz complete for Passive
# freq from ff: 10.0, actual freq: 10
# amp from ff: 0.1749072574326541, fom max-min/2 0.17490725735346757
# 10Hz complete for Passive
# freq from ff: 30.0, actual freq: 30
# amp from ff: 0.09789959578960851, fom max-min/2 0.09789956675940914
# 30Hz complete for Passive
# freq from ff: 50.0, actual freq: 50
# amp from ff: 0.06776456685153306, fom max-min/2 0.06776355231464493
# 50Hz complete for Passive
# freq from ff: 70.0, actual freq: 70
# amp from ff: 0.05260007022796473, fom max-min/2 0.05259999438615637
# 70Hz complete for Passive
# freq from ff: 90.0, actual freq: 90
# amp from ff: 0.04363042377013042, fom max-min/2 0.04363039753140896
# 90Hz complete for Passive
# freq from ff: 110.0, actual freq: 110
# amp from ff: 0.03781208667370099, fom max-min/2 0.037812022488168395
# 110Hz complete for Passive
# freq from ff: 130.0, actual freq: 130
# amp from ff: 0.03381170119887624, fom max-min/2 0.03381167341397884
# 130Hz complete for Passive
# freq from ff: 150.0, actual freq: 150
# amp from ff: 0.0309456013741536, fom max-min/2 0.030944826644457635
# 150Hz complete for Passive
# freq from ff: 170.0, actual freq: 170
# amp from ff: 0.028824832612171485, fom max-min/2 0.028824804164443663
# 170Hz complete for Passive
# freq from ff: 190.0, actual freq: 190
# amp from ff: 0.027212012961020018, fom max-min/2 0.027211979425914024
# 190Hz complete for Passive
# freq from ff: 200.0, actual freq: 200
# amp from ff: 0.026546277159724525, fom max-min/2 0.02654210141331248
# 200Hz complete for Passive
# freq from ff: 205.0, actual freq: 205
# amp from ff: 0.026242096039640374, fom max-min/2 0.02624209550474177
# 205Hz complete for Passive
# freq from ff: 210.0, actual freq: 210
# amp from ff: 0.02595502797346268, fom max-min/2 0.02595500162981068
# 210Hz complete for Passive
# freq from ff: 215.0, actual freq: 215
# amp from ff: 0.02568373777315921, fom max-min/2 0.025683727649301602
# 215Hz complete for Passive
# freq from ff: 220.0, actual freq: 220
# amp from ff: 0.025427011528453235, fom max-min/2 0.025426830389520205
# 220Hz complete for Passive
# freq from ff: 225.0, actual freq: 225
# amp from ff: 0.025183744101844686, fom max-min/2 0.02518373644590355
# 225Hz complete for Passive
# freq from ff: 230.0, actual freq: 230
# amp from ff: 0.024952928093838554, fom max-min/2 0.024952882775778562
# 230Hz complete for Passive
# freq from ff: 235.0, actual freq: 235
# amp from ff: 0.024733644079608767, fom max-min/2 0.024733637948592957
# 235Hz complete for Passive
# freq from ff: 240.0, actual freq: 240
# amp from ff: 0.02452505194922576, fom max-min/2 0.024524133513466495
# 240Hz complete for Passive
# freq from ff: 245.0, actual freq: 245
# amp from ff: 0.024326383208989413, fom max-min/2 0.024326379855182267
# 245Hz complete for Passive
# freq from ff: 250.0, actual freq: 250
# amp from ff: 0.024136934122485642, fom max-min/2 0.02412534740767569
# 250Hz complete for Passive
# freq from ff: 255.0, actual freq: 255
# amp from ff: 0.02395605958756609, fom max-min/2 0.023956056479789822
# 255Hz complete for Passive
# freq from ff: 260.0, actual freq: 260
# amp from ff: 0.02378316766001248, fom max-min/2 0.023783160785228574
# 260Hz complete for Passive
# freq from ff: 265.0, actual freq: 265
# amp from ff: 0.02361771464706359, fom max-min/2 0.023617707360095608
# 265Hz complete for Passive
# freq from ff: 270.0, actual freq: 270
# amp from ff: 0.02345920070427894, fom max-min/2 0.023459164467652727
# 270Hz complete for Passive
# freq from ff: 275.0, actual freq: 275
# amp from ff: 0.023307165878029418, fom max-min/2 0.023307162587776986
# 275Hz complete for Passive
# freq from ff: 280.0, actual freq: 280
# amp from ff: 0.023161186543363934, fom max-min/2 0.023160955254368787
# 280Hz complete for Passive
# freq from ff: 285.0, actual freq: 285
# amp from ff: 0.02302087219339835, fom max-min/2 0.023020869357118556
# 285Hz complete for Passive
# freq from ff: 290.0, actual freq: 290
# amp from ff: 0.022885862541783562, fom max-min/2 0.02288583029952207
# 290Hz complete for Passive
# freq from ff: 295.0, actual freq: 295
# amp from ff: 0.022755824904537272, fom max-min/2 0.022755815128078893
# 295Hz complete for Passive
# freq from ff: 300.0, actual freq: 300
# amp from ff: 0.02263045183157398, fom max-min/2 0.02262746865442722
# 300Hz complete for Passive
# freq from ff: 350.0, actual freq: 350
# amp from ff: 0.021579918864556045, fom max-min/2 0.021579876891635763
# 350Hz complete for Passive
# freq from ff: 400.0, actual freq: 400
# amp from ff: 0.020782612035855883, fom max-min/2 0.02073506575038664
# 400Hz complete for Passive
# freq from ff: 450.0, actual freq: 450
# amp from ff: 0.020138956353542743, fom max-min/2 0.020138551427486107
# 450Hz complete for Passive
# freq from ff: 500.0, actual freq: 500
# amp from ff: 0.019596375223596967, fom max-min/2 0.01951763241375204
# 500Hz complete for Passive
# freq from ff: 550.0, actual freq: 550
# amp from ff: 0.019125143819220976, fom max-min/2 0.019124829719103786
# 550Hz complete for Passive
# freq from ff: 600.0, actual freq: 600
# amp from ff: 0.018707324081188054, fom max-min/2 0.018707285813256647
# 600Hz complete for Passive
# freq from ff: 650.0, actual freq: 650
# amp from ff: 0.01833140186034352, fom max-min/2 0.018330796046512887
# 650Hz complete for Passive
# freq from ff: 700.0, actual freq: 700
# amp from ff: 0.017989552442004484, fom max-min/2 0.01798695693818786
# 700Hz complete for Passive
# freq from ff: 750.0, actual freq: 750
# amp from ff: 0.017676179705553227, fom max-min/2 0.0176586882858345
# 750Hz complete for Passive
# freq from ff: 800.0, actual freq: 800
# amp from ff: 0.017387100896400873, fom max-min/2 0.0172511735344969
# 800Hz complete for Passive
# freq from ff: 850.0, actual freq: 850
# amp from ff: 0.017119072348968502, fom max-min/2 0.01711906659657103
# 850Hz complete for Passive
# freq from ff: 900.0, actual freq: 900
# amp from ff: 0.0168695022018939, fom max-min/2 0.016869275288918573
# 900Hz complete for Passive
# freq from ff: 950.0, actual freq: 950
# amp from ff: 0.016636269375777227, fom max-min/2 0.016635619508008403
# 950Hz complete for Passive
# freq from ff: 1000.0, actual freq: 1000
# amp from ff: 0.016417605029945666, fom max-min/2 0.016413189551201413
# 1000Hz complete for Passive
# freq from ff: 1050.0, actual freq: 1050
# amp from ff: 0.016212011995558915, fom max-min/2 0.016211995009101088
# 1050Hz complete for Passive
# freq from ff: 1100.0, actual freq: 1100
# amp from ff: 0.01601820805919802, fom max-min/2 0.016016766814850314
# 1100Hz complete for Passive
# freq from ff: 1150.0, actual freq: 1150
# amp from ff: 0.015835084717404763, fom max-min/2 0.01583446578728598
# 1150Hz complete for Passive
# freq from ff: 1200.0, actual freq: 1200
# amp from ff: 0.01566167628914234, fom max-min/2 0.015618699430490324
# 1200Hz complete for Passive
# freq from ff: 1250.0, actual freq: 1250
# amp from ff: 0.015497136179568684, fom max-min/2 0.015497135899231296
# 1250Hz complete for Passive
# freq from ff: 1300.0, actual freq: 1300
# amp from ff: 0.015340718227664836, fom max-min/2 0.015340599845508507
# 1300Hz complete for Passive
# freq from ff: 1350.0, actual freq: 1350
# amp from ff: 0.01519176176799291, fom max-min/2 0.015191283975504177
# 1350Hz complete for Passive
# freq from ff: 1400.0, actual freq: 1400
# amp from ff: 0.015049679474826936, fom max-min/2 0.015048626334333903
# 1400Hz complete for Passive
# freq from ff: 1450.0, actual freq: 1450
# amp from ff: 0.014913947337808488, fom max-min/2 0.014913828182351097
# 1450Hz complete for Passive
# freq from ff: 1500.0, actual freq: 1500
# amp from ff: 0.014784096303345436, fom max-min/2 0.014781325088165431
# 1500Hz complete for Passive
# freq from ff: 1550.0, actual freq: 1550
# amp from ff: 0.014659705240367539, fom max-min/2 0.014659621585551008
# 1550Hz complete for Passive
# freq from ff: 1600.0, actual freq: 1600
# amp from ff: 0.014540394974762151, fom max-min/2 0.014520784293964084
# 1600Hz complete for Passive
# freq from ff: 1650.0, actual freq: 1650
# amp from ff: 0.01442582319721102, fom max-min/2 0.01442521950598774
# 1650Hz complete for Passive
# freq from ff: 1700.0, actual freq: 1700
# amp from ff: 0.014315680092537846, fom max-min/2 0.014315449228398336
# 1700Hz complete for Passive
# freq from ff: 1750.0, actual freq: 1750
# amp from ff: 0.014209684570625662, fom max-min/2 0.014199953592708425
# 1750Hz complete for Passive
# freq from ff: 1800.0, actual freq: 1800
# amp from ff: 0.014107581002778844, fom max-min/2 0.014097313653849142
# 1800Hz complete for Passive
# freq from ff: 1850.0, actual freq: 1850
# amp from ff: 0.014009136385508273, fom max-min/2 0.014008997712309679
# 1850Hz complete for Passive
# freq from ff: 1900.0, actual freq: 1900
# amp from ff: 0.01391413786810655, fom max-min/2 0.013913720445046351
# 1900Hz complete for Passive
# freq from ff: 1950.0, actual freq: 1950
# amp from ff: 0.013822390590960526, fom max-min/2 0.013821876277376077
# 1950Hz complete for Passive
# freq from ff: 2000.0, actual freq: 2000
# amp from ff: 0.013733715790730777, fom max-min/2 0.012951231870118818
# 2000Hz complete for Passive
# Simulation for Passive hay cell complete

# %% [markdown]
# ### Plot differences

# %%
plt.figure(figsize=(5, 3.5))  # Set the figure size
#plt.loglog(freq, soma_amplitudes_active_old, linestyle=':', color='tab:blue', markersize=5, linewidth=2, label = 'Active Hay neuron old')
plt.loglog(freq, soma_amplitudes_active, linestyle='-', color='tab:blue', markersize=5, linewidth=2, label = 'Active Hay neuron')
#plt.loglog(freq, soma_amplitudes_passive_old, linestyle=':', color='tab:orange', markersize=5, linewidth=2, label = 'Passive Hay neuron old')
plt.loglog(freq, soma_amplitudes_passive, linestyle='-', color='tab:orange', markersize=5, linewidth=2, label = 'Passive Hay neuron')
plt.xlabel('Frequency [Hz]', fontsize=10)
plt.ylabel(r'Soma $V_m$ Amplitude [mV]', fontsize=10)
#plt.title('Soma Vmem Amplitude vs Frequency', fontsize=12)
plt.legend()
plt.xlim(left=1)  # Start the x-axis from 2
plt.grid(True, linestyle='--', linewidth=0.5)
plt.tight_layout() 
plt.savefig('Hay_cell_active_and_passive_soma_amp_vs_freq')
plt.show()

# %%
def plot_vmem_both(plot_data_both):
    numrows = 4  # Two for Active, two for Passive
    numcols = len(plot_data_both['Active']['freq']) // 2 + 1
    fig, axes = plt.subplots(numrows, numcols, figsize=(12, 8), gridspec_kw={'height_ratios': [1, 1, 1, 1], 'width_ratios': [1] * numcols})

    for row in range(numrows):
        axes[row,0].set_xticks([])
        axes[row,0].set_yticks([])
        axes[row,0].set_frame_on(False)

    conditions = ['Active', 'Passive']


    # Add label A and C above morphology plots
    fig.text(0.005, 0.99, 'A', fontsize=16, fontweight='bold', va='top', ha='center')
    fig.text(0.005, 0.5, 'C', fontsize=16, fontweight='bold', va='top', ha='center')

    
    # Add label B and D above the membrane potential plots
    fig.text(0.16, 0.99, 'B', fontsize=16, fontweight='bold', va='top', ha='center')
    fig.text(0.16, 0.5, 'D', fontsize=16, fontweight='bold', va='top', ha='center')
    
    
    for condition_idx, condition in enumerate(conditions):
        plot_data = plot_data_both[condition]

        # Extract data
        selected_segments = plot_data['selected_segments']
        #colors = plot_data['colors']
        colors = ['tab:blue', 'tab:orange', 'tab:olive']
        totnsegs = int(plot_data['totnsegs'])
        x = np.array(plot_data['x'])
        z = np.array(plot_data['z'])
        tvec = np.array(plot_data['tvec'])
        soma_vmem = np.array(plot_data['soma_vmem'])
        idx1_vmem = np.array(plot_data['idx1_vmem'])
        idx2_vmem = np.array(plot_data['idx2_vmem'])

        # Define the starting row index (0 for Active, 2 for Passive)
        start_row = condition_idx * 2

        # First column: Cell shape
        ax1 = plt.subplot2grid((numrows, numcols), (start_row, 0), rowspan=2)
        ax1.set_aspect(1)
        ax1.set_xticks([])
        ax1.set_xlabel('x [µm]')
        ax1.set_ylabel('z [µm]')
        ax1.set_title(f'{condition}')

        for idx_seg in range(totnsegs):
            ax1.plot(x[idx_seg], z[idx_seg], c='k')

        for idx, color in zip(selected_segments, colors):
            ax1.plot(x.mean(axis=-1)[idx], z.mean(axis=-1)[idx], 'o', color=color, label=f"Segment {idx}", markersize = 8)

        #ax1.legend(fontsize='x-small')

        # Remaining columns: Membrane potential over time for each frequency
        for i, f in enumerate(plot_data['freq']):
            row = start_row + (i // 4)  # Distribute over two rows per condition
            col = (i % 4) + 1
            ax = axes[row, col]

            ax.set_xlabel('Time [ms]')
            if col == 1:
                ax.set_ylabel('Membrane Potential [mV]')
            ax.set_title(f"{f} Hz {condition}")

            ax.plot(tvec, idx1_vmem[i], color=colors[1], label=f'Segment {plot_data['selected_segments'][1]}', linewidth=0.5, alpha=0.5)
            ax.plot(tvec, idx2_vmem[i], color=colors[2], label=f'Segment {plot_data['selected_segments'][2]}', linewidth=0.5, alpha=0.5)
            ax.plot(tvec, soma_vmem[i], color=colors[0], label='Soma', linewidth=0.5, alpha=0.5)

            #ax.legend(fontsize='x-small')

    # Create a common legend underneath all plots
    handles = [
        plt.Line2D([0], [0], color=colors[0], label='Soma', linewidth=2, alpha=0.9),
        plt.Line2D([0], [0], color=colors[1], label=f'Segment {selected_segments[1]}', linewidth=2, alpha=0.7),
        plt.Line2D([0], [0], color=colors[2], label=f'Segment {selected_segments[2]}', linewidth=2, alpha=0.7)
    ]

    fig.legend(handles=handles, loc='lower center', bbox_to_anchor=(0.5, -0.05), ncol=3, frameon=False, fontsize = 14)

    fig.set_constrained_layout(True)
    plt.savefig('Hay_cell_active_vs_passive_cell_shape_and_vmem_plots')
    plt.show()


plot_vmem_both(plot_data_both)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.gridspec import GridSpec

def plot_vmem_both(plot_data_both):
    conditions = ['Active', 'Passive']
    num_conditions = len(conditions)
    freq_count = len(plot_data_both['Active']['freq'])
    numcols = freq_count // 2 + 1  # +1 for morphology column
    numrows = num_conditions * 2  # 2 rows per condition

    fig = plt.figure(figsize=(14, 9), constrained_layout=True)
    gs = GridSpec(numrows + 1, numcols, figure=fig, height_ratios=[10] * numrows + [1])

    axes = np.empty((numrows, numcols), dtype=object)

    for condition_idx, condition in enumerate(conditions):
        plot_data = plot_data_both[condition]

        selected_segments = plot_data['selected_segments']
        colors = ['tab:blue', 'tab:orange', 'tab:olive']
        totnsegs = int(plot_data['totnsegs'])
        x = np.array(plot_data['x'])
        z = np.array(plot_data['z'])
        tvec = np.array(plot_data['tvec'])
        soma_vmem = np.array(plot_data['soma_vmem'])
        idx1_vmem = np.array(plot_data['idx1_vmem'])
        idx2_vmem = np.array(plot_data['idx2_vmem'])

        start_row = condition_idx * 2

        # Morphology plot (rowspan=2, col=0)
        ax1 = fig.add_subplot(gs[start_row:start_row+2, 0])
        ax1.set_aspect(1)
        ax1.set_xticks([])
        ax1.set_yticks([])
        ax1.set_xlabel('x [µm]')
        ax1.set_ylabel('z [µm]')
        ax1.set_title(f'{condition}', fontsize=12)

        for idx_seg in range(totnsegs):
            ax1.plot(x[idx_seg], z[idx_seg], c='k')

        for idx, color in zip(selected_segments, colors):
            ax1.plot(x.mean(axis=-1)[idx], z.mean(axis=-1)[idx], 'o', color=color, label=f"Segment {idx}", markersize=8)

        # Label morphology panels
        label_char = chr(65 + condition_idx * 2)  # A for active, C for passive
        ax1.text(-0.15, 1.05, label_char, transform=ax1.transAxes, fontsize=16, fontweight='bold')

        # Membrane potential plots
        for i, f in enumerate(plot_data['freq']):
            row = start_row + i // (numcols - 1)
            col = (i % (numcols - 1)) + 1
            ax = fig.add_subplot(gs[row, col])
            axes[row, col] = ax

            ax.set_xlabel('Time [ms]')
            if col == 1:
                ax.set_ylabel('Membrane Potential [mV]')
            ax.set_title(f"{f} Hz", fontsize=10)

            ax.plot(tvec, idx1_vmem[i], color=colors[1], label=f'Segment {selected_segments[1]}', linewidth=0.6, alpha=0.6)
            ax.plot(tvec, idx2_vmem[i], color=colors[2], label=f'Segment {selected_segments[2]}', linewidth=0.6, alpha=0.6)
            ax.plot(tvec, soma_vmem[i], color=colors[0], label='Soma', linewidth=0.8, alpha=0.8)

            # Label membrane panels
            if i == 0:
                label_char = chr(66 + condition_idx * 2)  # B for active, D for passive
                ax.text(-0.15, 1.15, label_char, transform=ax.transAxes, fontsize=16, fontweight='bold')

    # Create a dedicated subplot for legend (bottom row)
    legend_ax = fig.add_subplot(gs[-1, :])
    legend_ax.axis('off')

    handles = [
        plt.Line2D([0], [0], color=colors[0], label='Soma', linewidth=2, alpha=0.9),
        plt.Line2D([0], [0], color=colors[1], label=f'Segment {selected_segments[1]}', linewidth=2, alpha=0.7),
        plt.Line2D([0], [0], color=colors[2], label=f'Segment {selected_segments[2]}', linewidth=2, alpha=0.7)
    ]

    legend_ax.legend(handles=handles, loc='center', ncol=3, frameon=False, fontsize=13)

    plt.savefig('Hay_cell_active_vs_passive_cell_shape_and_vmem_plots.png', dpi=300)
    plt.show()


plot_vmem_both(plot_data_both)

# %% [markdown]
# ## Mann-Whitney U

# %%
print(f'soma amplitudes active hay neuron: {soma_amplitudes_active}')
print(f'soma amplitudes passive hay neuron: {soma_amplitudes_passive}')
# Out:
# soma amplitudes active hay neuron: [0.2092056600062792, 0.22118488694408117, 0.2156045282868317, 0.19501705887844398, 0.174252192479984, 0.1657801422018538, 0.09532185248497264, 0.0671143877150779, 0.05232661859845864, 0.04347089881253615, 0.03769988581767501, 0.03372366885398725, 0.030871569264618984, 0.028759595746543135, 0.02715265157023672, 0.026489155242126187, 0.02618596480246442, 0.025899814390583108, 0.025629377059336926, 0.025373446123831505, 0.025130922791876207, 0.02490080524426325, 0.024682178969697398, 0.024474208189318964, 0.024276128230673374, 0.024087238731566277, 0.023906897571542133, 0.02373451544291405, 0.023569550985658428, 0.023411506420387255, 0.023259923622474313, 0.023114380587671752, 0.022974488245860927, 0.02283988758495422, 0.02271024705159481, 0.02258526019930945, 0.021538145671645925, 0.02074372828039371, 0.020102614240903687, 0.019562297021343156, 0.019093089107253224, 0.01867707990153593, 0.01830277913485814, 0.017962383828722922, 0.017650317636979117, 0.017362415581533522, 0.01709544978338567, 0.016846842264946253, 0.016614484072470355, 0.01639661690698691, 0.01619175273960879, 0.01599861727184572, 0.015816108853465776, 0.015643267741752166, 0.015479252494433493, 0.015323321429478728, 0.015174817783432711, 0.015033157638120544, 0.014897819966720573, 0.014768338335038421, 0.0146442939181101, 0.014525309577869317, 0.014411044807682728, 0.014301191393001327, 0.01419546966886112, 0.014093625278973385, 0.013995426359029173, 0.013900661080855286, 0.01380913550508854, 0.013720671698695872]
# soma amplitudes passive hay neuron: [0.2299584290987912, 0.22055245012551505, 0.20764314274606363, 0.194179553995847, 0.18113017953084973, 0.1749072574326541, 0.09789959578960851, 0.06776456685153306, 0.05260007022796473, 0.04363042377013042, 0.03781208667370099, 0.03381170119887624, 0.0309456013741536, 0.028824832612171485, 0.027212012961020018, 0.026546277159724525, 0.026242096039640374, 0.02595502797346268, 0.02568373777315921, 0.025427011528453235, 0.025183744101844686, 0.024952928093838554, 0.024733644079608767, 0.02452505194922576, 0.024326383208989413, 0.024136934122485642, 0.02395605958756609, 0.02378316766001248, 0.02361771464706359, 0.02345920070427894, 0.023307165878029418, 0.023161186543363934, 0.02302087219339835, 0.022885862541783562, 0.022755824904537272, 0.02263045183157398, 0.021579918864556045, 0.020782612035855883, 0.020138956353542743, 0.019596375223596967, 0.019125143819220976, 0.018707324081188054, 0.01833140186034352, 0.017989552442004484, 0.017676179705553227, 0.017387100896400873, 0.017119072348968502, 0.0168695022018939, 0.016636269375777227, 0.016417605029945666, 0.016212011995558915, 0.01601820805919802, 0.015835084717404763, 0.01566167628914234, 0.015497136179568684, 0.015340718227664836, 0.01519176176799291, 0.015049679474826936, 0.014913947337808488, 0.014784096303345436, 0.014659705240367539, 0.014540394974762151, 0.01442582319721102, 0.014315680092537846, 0.014209684570625662, 0.014107581002778844, 0.014009136385508273, 0.01391413786810655, 0.013822390590960526, 0.013733715790730777]

# %%
mw_12_stat, mw_12_p = mannwhitneyu(soma_amplitudes_active, soma_amplitudes_passive, alternative='two-sided')

print(f"Mann-Whitney U Test (Data1 vs Data2) (with remove_list and fourier): U={mw_12_stat}, p={mw_12_p}")
# Out:
# Mann-Whitney U Test (Data1 vs Data2) (with remove_list and fourier): U=2416.0, p=0.8889652671902902
